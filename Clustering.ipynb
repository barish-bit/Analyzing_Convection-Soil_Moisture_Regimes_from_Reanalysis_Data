# %% [markdown]
# <a href="https://colab.research.google.com/github/barish-bit/Analyzing_Convection-Soil_Moisture_Regimes_from_Reanalysis_Data/blob/main/Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
fields=["sl no","grid_1"]
rows=[[1, 13],
     [2, 12],
     [3, 13],
     [4, 17],
     [5, 19],
     [6, 15],
     [7, 12],
     [8, 11],
     [9, 19],
     [10,15],
     [11, 13],
     [12, 12],
     [13, 13],
     [14, 17],
     [15, 18],
     [16, 15],
     [17, 13],
     [18, 11],
     [19, 11],
     [20,15],
     [21, 23],
     [22, 15],
     [23, 13],
     [24, 18],
     [25, 11],
     [26, 10],
     [27, 13],
     [28, 11],
     [29, 17],
     [30,15],
     [31, 13],
     [32, 21],
     [33, 19],
     [34, 17],
     [35, 11],
     [36, 15],
     [37, 19],
     [38, 15],
     [39, 10],
     [40,13]]
filename="mycsv.csv"
with open(filename, 'w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields)
    csvwriter.writerows(rows)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random as rd
import matplotlib.pyplot as plt
from math import sqrt

# %%
data = pd.read_csv("/content/mycsv.csv")
#for j in range (4):
 #for i in range (4+j*10,10+j*10):
  #data.drop([i],axis=0,inplace=True)
  #data.to_csv("sdfg.csv")
#data.head()
list=[13,12,17]
#data.drop(data.index[(data["grid_1"] == list)],axis=0,inplace=True)
df=(data[data.grid_1.isin(list)==False])
#data = data.drop(labels=list, axis=1)
#data = data[data.grid_1 != 13]
df.head()
# Out:
#    sl no  grid_1
# 4      5      19
# 5      6      15
# 7      8      11
# 8      9      19
# 9     10      15

# %%
data = pd.read_csv("/content/Final_30Years.csv")
X=data[["TIME","Grid_1","Grid_2"]]

plt.scatter(X["TIME"], X["Grid_1"], c="blue")
plt.scatter(X["TIME"],X["Grid_2"],c="red")

plt.xlabel("TIME")
plt.ylabel("Grid_1&2)")
plt.show()

# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

plt.style.use('seaborn')
data = pd.read_csv("/content/FINAL_30Years.csv")
X=data[["TIME","Grid_1","Grid_2","Grid_4","Grid_5","Grid_6","Grid_7","Grid_8","Grid_9","Grid_10","Grid_11"]]
X['TIME'] = pd.to_datetime(X['TIME'])
X.sort_values('TIME', inplace=True)
#plt.scatter(X["TIME"],X["Grid_3"],c="red")
plt.scatter(X["TIME"], X["Grid_1"], c="red")
plt.scatter(X["TIME"], X["Grid_8"], c="red")
plt.scatter(X["TIME"], X["Grid_9"], c="red")
plt.scatter(X["TIME"], X["Grid_10"], c="red")
plt.scatter(X["TIME"], X["Grid_11"], c="red")
#plt.xlabel("TIME")
#plt.ylabel("Grid_1)")
#plt.show()
plt.scatter(X["TIME"],X["Grid_2"],c="green")
plt.scatter(X["TIME"],X["Grid_4"],c="green")
plt.scatter(X["TIME"],X["Grid_5"],c="green")
plt.scatter(X["TIME"],X["Grid_6"],c="green")
plt.scatter(X["TIME"],X["Grid_7"],c="green")

plt.gcf().autofmt_xdate()
plt.xlabel("TIME")
plt.ylabel("Rainfall")
plt.tight_layout()
plt.title("Rajasthan_vs_Middle_India")
plt.show()
# Out:
# <ipython-input-16-846f106f388a>:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <ipython-input-16-846f106f388a>:9: UserWarning: Parsing '13-06-1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   X['TIME'] = pd.to_datetime(X['TIME'])
# <ipython-input-16-846f106f388a>:9: UserWarning: Parsing '14-06-1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   X['TIME'] = pd.to_datetime(X['TIME'])
# <ipython-input-16-846f106f388a>:9: UserWarning: Parsing '15-06-1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   X['TIME'] = pd.to_datetime(X['TIME'])
# ...

# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

plt.style.use('seaborn')

data = pd.read_csv('/content/Final_30Years.csv')

data['TIME'] = pd.to_datetime(data['TIME'])
data.sort_values('TIME', inplace=True)

price_date = data['TIME']
price_close = data['Grid_1']

plt.scatter(price_date, price_close)

plt.gcf().autofmt_xdate()

plt.title('Rainfall Pune average data')
plt.xlabel('Date')
plt.ylabel('Rainfall')

plt.tight_layout()

plt.show()
# Out:
# <ipython-input-22-72a92f286569>:10: UserWarning: Parsing '13-06-1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data['TIME'] = pd.to_datetime(data['TIME'])
# <ipython-input-22-72a92f286569>:10: UserWarning: Parsing '14-06-1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data['TIME'] = pd.to_datetime(data['TIME'])
# <ipython-input-22-72a92f286569>:10: UserWarning: Parsing '15-06-1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data['TIME'] = pd.to_datetime(data['TIME'])
# <ipython-input-22-72a92f286569>:10: UserWarning: Parsing '16-06-1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data['TIME'] = pd.to_datetime(data['TIME'])
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# step 1 and 2

# number of centriod
K=2

# select random observation as a centriod
Centroids = (X.sample(n=K))
plt.scatter(X["sl no"], X["grid 1"], c="blue")
plt.scatter(Centroids["sl no"], Centroids["grid 1"], c="red")
plt.xlabel("sl no")
plt.ylabel("grid 1")
plt.show()

# %%
diff = 1
j=0

while(diff!=0):
    XD=X
    i=1
    for index1, row_c in Centroids.iterrows():
        ED=[]
        for index2, row_d in XD.iterrows():
            d1 = (row_c["sl no"]-row_d["sl no"])**2
            d2 = (row_c["grid 1"]-row_d["grid 1"])**2
            d = sqrt(d1+d2)
            ED.append(d)
        X[i] = ED
        i = i+1

    C = []
    for index, row in X.iterrows():
        min_dist=row[1]
        pos=1
        for i in range(K):
            if row[i+1] < min_dist:
                min_dist = row[i+1]
                pos = i+1
        C.append(pos)
    X["Cluster"]=C
    Centroids_new = X.groupby(["Cluster"]).mean()[["grid 1", "sl no"]]
    if j == 0:
        diff = 1
        j = j+1
    else:
        diff = (Centroids_new['grid 1'] - Centroids['grid 1']).sum() + (Centroids_new['sl no'] - Centroids['sl no']).sum()
        print(diff.sum())
    Centroids = X.groupby(["Cluster"]).mean()[["grid 1","sl no"]]
# Out:
# -5.2066666666666634
# -2.0065473145780057
# -2.008089276900691
# 0.0

# %%
color=['blue','green']
for k in range(K):
    data=X[X["Cluster"]==k+1]
    plt.scatter(data["sl no"],data["grid 1"],c=color[k])
plt.scatter(Centroids["sl no"],Centroids["grid 1"],c='red')
plt.xlabel('sl no')
plt.ylabel('grid 1')
plt.show()

# %%
import csv
fields=["sl no","grid 1", "grid 2"]
rows=[[1, 13, 2],
     [2, 12, 4],
     [3, 13, 3],
     [4, 17, 5],
     [5, 19,7],
     [6, 15, 1],
     [7, 12, 0],
     [8, 11,4],
     [9, 19,9],
     [10,15,11],
     [11, 13, 0],
     [12, 12,6],
     [13, 13,8],
     [14, 17,9],
     [15, 18,3],
     [16, 15,6],
     [17, 13, 5],
     [18, 11,8],
     [19, 11,2],
     [20,15,6],
     [21, 23,8],
     [22, 15,4],
     [23, 13,1],
     [24, 18,8],
     [25, 11,4],
     [26, 10,6],
     [27, 13,9],
     [28, 11,5],
     [29, 17,9],
     [30,15,4],
     [31, 13,2],
     [32, 21,5],
     [33, 19,1],
     [34, 17,4],
     [35, 11,2],
     [36, 15,4],
     [37, 19,9],
     [38, 15,4],
     [39, 10,1],
     [40,13,8]]
filename="mycsv.csv"
with open(filename, 'w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields)
    csvwriter.writerows(rows)

# %%
data = pd.read_csv("/content/mycsv.csv")
data.head()
# Out:
#    sl no  grid 1  grid 2
# 0      1      13       2
# 1      2      12       4
# 2      3      13       3
# 3      4      17       5
# 4      5      19       7

# %%
X=data[["sl no","grid 1", "grid 2"]]
plt.scatter(X["sl no"], X["grid 1"], c="blue")
plt.scatter(X["sl no"],X["grid 2"], c="blue")
plt.xlabel("sl no")
plt.ylabel("grid 1)")
plt.show()

# %%
# step 1 and 2

# number of centriod
K=2

# select random observation as a centriod
Centroids = (X.sample(n=K))
plt.scatter(X["sl no"], X["grid 1"], c="blue")
plt.scatter(X["sl no"],X["grid 2"], c="blue")
plt.scatter(Centroids["sl no"], Centroids["grid 1"], c="red")
plt.xlabel("sl no")
plt.ylabel("grid 1")
plt.show()

# %%
diff = 1
j=0

while(diff!=0):
    XD=X
    i=1
    for index1, row_c in Centroids.iterrows():
        ED=[]
        for index2, row_d in XD.iterrows():
          for i in range (2):
            d1 = (row_c["sl no"]-row_d["sl no"])**2
            d2 = (row_c["grid "+int[i]]-row_d["grid "+int[i]])**2
            d = sqrt(d1+d2)
            ED.append(d)
        X[i] = ED
        i = i+1

    C = []
    for index, row in X.iterrows():
        min_dist=row[1]
        pos=1
        for i in range(K):
            if row[i+1] < min_dist:
                min_dist = row[i+1]
                pos = i+1
        C.append(pos)
    X["Cluster"]=C
    Centroids_new = X.groupby(["Cluster"]).mean()[["grid "+int[i], "sl no"]]
    if j == 0:
        diff = 1
        j = j+1
    else:
        diff = (Centroids_new['grid '+int[i]] - Centroids['grid '+int[i]]).sum() + (Centroids_new['sl no'] - Centroids['sl no']).sum()
        print(diff.sum())
    Centroids = X.groupby(["Cluster"]).mean()[["grid "+int[i],"sl no"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-83b902293bbf> in <module>
#      10           for i in range (2):
#      11             d1 = (row_c["sl no"]-row_d["sl no"])**2
# ---> 12             d2 = (row_c["grid "+int[i]]-row_d["grid "+int[i]])**2
#      13             d = sqrt(d1+d2)
#      14             ED.append(d)
#
# TypeError: 'type' object is not subscriptable

# %%
color=['blue','green']
for k in range(K):
    data=X[X["Cluster"]==k+1]
    plt.scatter(data["sl no"],data["grid 1"],c=color[k])
plt.scatter(Centroids["sl no"],Centroids["grid 1"],c='red')
plt.xlabel('sl no')
plt.ylabel('grid 1')
plt.show()

# %%
import xarray as xr
import pandas as pd

# list of netCDF files
files = ["/content/drive/MyDrive/RF25_IMD0p252021.nc","/content/drive/MyDrive/RF25_IMD0p252020.nc","/content/drive/MyDrive/RF25_IMD0p252019.nc","/content/drive/MyDrive/RF25_IMD0p252018.nc","/content/drive/MyDrive/RF25_IMD0p252017.nc",]

# concatenate all files into a single xarray dataset
ds = xr.concat([xr.open_dataset(f) for f in files], dim='TIME')

# extract time series data for a specific variable
data = ds['RAINFALL'].to_dataframe()

# save to CSV file
data.to_csv('time_series.csv')

# %%
import xarray as xr
import pandas as pd
import numpy as np
# list of netCDF files
#files = ["/content/drive/MyDrive/RF25_IMD0p252021.nc","/content/drive/MyDrive/RF25_IMD0p252020.nc","/content/drive/MyDrive/RF25_IMD0p252019.nc","/content/drive/MyDrive/RF25_IMD0p252018.nc","/content/drive/MyDrive/RF25_IMD0p252017.nc",]
files=[]
for i in range (15):
  a="/content/drive/MyDrive/RF25_ind"+str(2007+i)+"_rfp25.nc"
  files += [a]
#files=np.array(files)
#print(files)
# concatenate all files into a single xarray dataset
ds = xr.concat([xr.open_dataset(f) for f in files], dim='TIME')

# extract time series data for a specific variable
data = ds['RAINFALL'].to_dataframe()

# save to CSV file
data.to_csv('time_series_l15years_rainfall.csv')

# %%
#Extracting one longitude-latitude data from the 5 year data set and plotting them
from netCDF4 import Dataset

import numpy as np
data= Dataset(r"/content/drive/MyDrive/RF25_IMD0p252021.nc")

lons= data.variables["LONGITUDE"][:]

lats= data.variables["LATITUDE"][:]

time=data.variables["TIME"]

time= data.variables["TIME"][:]

lat_my= float(input("Enter the latitude:"))
lon_my= float(input("Enter the longitude:" ))
sq_diff_lat=(lats-lat_my)**2
sq_diff_lon=(lons-lon_my)**2
min_index_lat=sq_diff_lat.argmin()
min_index_lon=sq_diff_lon.argmin()
longi=lons[min_index_lon]
lati=lats[min_index_lat]
print(min_index_lat,min_index_lon)
print(longi,lati)
# Out:
# Enter the latitude:25.2975
# Enter the longitude:91.5926
# 75 100
# 91.5 25.25

# %%
import xarray as xr

#ds =xr.open_mfdataset(['/content/RF25_IMD0p252017.nc', '/content/RF25_IMD0p252018.nc', '/content/RF25_IMD0p252019.nc','/content/RF25_IMD0p252020.nc','/content/RF25_IMD0p252021.nc'])
#ds = ds.sortby('TIME')

ds_latlon = ds.sel(LONGITUDE=longi, LATITUDE=lati)

df = ds_latlon.to_dataframe()
list= ["29-02-2020"]
df=df.TIME.isin(list)==False

df=df.iloc[(31*3+30*1+28*1):,:]
df=df.iloc[:-(31*2 + 30*1 + 28*0), :]
df=df.iloc[ : : , : ]


df.to_csv('Five year data of that lon-lat of Bangalore1.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-1a0b817a5c32> in <module>
#       1 import xarray as xr
#       2
# ----> 3 ds =xr.open_mfdataset(['/content/RF25_IMD0p252017.nc', '/content/RF25_IMD0p252018.nc', '/content/RF25_IMD0p252019.nc','/content/RF25_IMD0p252020.nc','/content/RF25_IMD0p252021.nc'])
#       4 ds = ds.sortby('TIME')
#       5
#
# /usr/local/lib/python3.9/dist-packages/xarray/backends/api.py in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1023             # Redo ordering from coordinates, ignoring how they were ordered
#    1024             # previously
# -> 1025             combined = combine_by_coords(
#    1026                 datasets,
#    1027                 compat=compat,
#
# ...

# %%
import pandas as pd
data = pd.read_csv("/content/Five year data of that lon-lat of Bangalore1.csv")
data.head()
# Out:
#          TIME  LONGITUDE  LATITUDE  RAINFALL
# 0  2017-06-01       66.5      38.5       NaN
# 1  2017-06-02       66.5      38.5       NaN
# 2  2017-06-03       66.5      38.5       NaN
# 3  2017-06-04       66.5      38.5       NaN
# 4  2017-06-05       66.5      38.5       NaN

# %%
print(31*3+30*1+28*1)
print(151+122)
print(365+151)
# Out:
# 151
# 273
# 516

# %%
pip install netCDF4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 38.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.1 MB/s eta 0:00:00
# ...

# %%
import numpy as np
from netCDF4 import Dataset
data= Dataset(r"/content/RF25_IMD0p252021.nc")

lons= data.variables["LONGITUDE"][:]

lats= data.variables["LATITUDE"][:]

time=data.variables["TIME"]

time= data.variables["TIME"][:]
list=[[12, 77],[13, 88],[14, 99]]
list1=[]
for i in range (len(list)):
  lat_my= list[i][0]
  lon_my= list[i][1]
  sq_diff_lat=(lats-lat_my)**2
  sq_diff_lon=(lons-lon_my)**2
  min_index_lat=sq_diff_lat.argmin()
  min_index_lon=sq_diff_lon.argmin()
  a1=lons[min_index_lon]
  a2=lats[min_index_lat]
  list1.append([a1,a2])
list1=np.array(list1)
print(list1)
print(list1[1][1])
#print(min_index_lat,min_index_lon)
#print(longi,lati)'''
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-4de1c2c7d88b> in <module>
#       1 import numpy as np
#       2 from netCDF4 import Dataset
# ----> 3 data= Dataset(r"/content/RF25_IMD0p252021.nc")
#       4
#       5 lons= data.variables["LONGITUDE"][:]
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/RF25_IMD0p252021.nc'

# %%
import xarray as xr
import pandas as pd
df = pd.read_csv("/content/time_series.csv")
#ds =xr.open_mfdataset(['/content/drive/MyDrive/RF25_IMD0p252017.nc', '/content/drive/MyDrive/RF25_IMD0p252018.nc', '/content/drive/MyDrive/RF25_IMD0p252019.nc','/content/drive/MyDrive/RF25_IMD0p252020.nc','/content/RF25_IMD0p252021.nc'])
#ds = ds.sortby('TIME')
#for k in range (len(list1)):
#ds_latlon = ds.sel(LONGITUDE=longi, LATITUDE=lati)

#df = ds_latlon.to_dataframe()
list1=[77]
df.LONGITUDE.isin(list1)==True
list2=[13]
df.LATITUDE.isin(list2)==True
list= ["29-02-2020"]
df.TIME.isin(list)==False

df=df.iloc[(31*3+30*1+28*1):,:]
df=df.iloc[:-(31*2 + 30*1 + 28*0), :]
for j in range (4):
  for i in range (273+j*365,516+j*365):
    df.drop([i],axis=0,inplace=True)
    #df.to_csv("sdfg.csv")
#data.head()


df.to_csv('Five year data of that lon-lat of Bangalore11.csv')

# %%
pip install netCDF4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 37.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 13.9 MB/s eta 0:00:00
# ...

# %%
import numpy as np
from netCDF4 import Dataset
data= Dataset(r"/content/drive/MyDrive/RF25_IMD0p252017.nc")
print(data)
lons= data.variables["LONGITUDE"][:]
print(lons)
lats= data.variables["LATITUDE"][:]
print(lats)
print(data.variables["LONGITUDE"][43])
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     history: FERRET V7.5 (optimized) 16-Mar-22
#     Conventions: CF-1.6
#     dimensions(sizes): LONGITUDE(135), LATITUDE(129), TIME(365)
#     variables(dimensions): float64 LONGITUDE(LONGITUDE), float64 LATITUDE(LATITUDE), float64 TIME(TIME), float64 RAINFALL(TIME, LATITUDE, LONGITUDE)
#     groups:
# [ 66.5   66.75  67.    67.25  67.5   67.75  68.    68.25  68.5   68.75
#   69.    69.25  69.5   69.75  70.    70.25  70.5   70.75  71.    71.25
#   71.5   71.75  72.    72.25  72.5   72.75  73.    73.25  73.5   73.75
#   74.    74.25  74.5   74.75  75.    75.25  75.5   75.75  76.    76.25
#   76.5   76.75  77.    77.25  77.5   77.75  78.    78.25  78.5   78.75
#   79.    79.25  79.5   79.75  80.    80.25  80.5   80.75  81.    81.25
#   81.5   81.75  82.    82.25  82.5   82.75  83.    83.25  83.5   83.75
#   84.    84.25  84.5   84.75  85.    85.25  85.5   85.75  86.    86.25
# ...

# %%
'''import numpy as np
days=[]
for i in range (21):
  b=10+i
  days += [b]
days=np.array(days)
print(days)'''
import numpy as np
year_list=[]
for i in range (30):
  a=1992+i
  #a="year"+str(a)
  year_list+=[a]
year_list=np.array(year_list)
print(year_list)
list1=[]
month=[1,3,5]
for i in range (31):
  for j in month:
    for k in range (30):
      if i+1 <=9:
        a=str(year_list[k])+"-0"+str(j)+"-0"+str(i+1)
        list1 +=[a]
      else:
        a=str(year_list[k])+"-0"+str(j)+"-"+str(i+1)
        list1+=[a]
month=[4]
for i in range (30):
  for j in month:
    for k in range (30):
     if i+1 <=9:
        a=str(year_list[k])+"-0"+str(j)+"-0"+str(i+1)
        list1 +=[a]
     else:
        a=str(year_list[k])+"-0"+str(j)+"-"+str(i+1)
        list1+=[a]
month=[2]
for i in range (28):
  for j in month:
    for k in range (30):
     if i+1 <=9:
        a=str(year_list[k])+"-0"+str(j)+"-0"+str(i+1)
        list1 +=[a]
     else:
        a=str(year_list[k])+"-0"+str(j)+"-"+str(i+1)
        list1+=[a]
month=[10,12]
for i in range (31):
  for j in month:
    for k in range (30):
     if i+1 <=9:
        a=str(year_list[k])+"-"+str(j)+"-0"+str(i+1)
        list1 +=[a]
     else:
        a=str(year_list[k])+"-"+str(j)+"-"+str(i+1)
        list1+=[a]
month=[11]
for i in range (30):
  for j in month:
    for k in range (30):
     if i+1 <=9:
        a=str(year_list[k])+"-"+str(j)+"-0"+str(i+1)
        list1 +=[a]
     else:
        a=str(year_list[k])+"-"+str(j)+"-"+str(i+1)
        list1+=[a]
year_list1=np.array(list1)
year_list1=year_list1.tolist()
#print(year_list1)
import xarray as xr
import pandas as pd
df = pd.read_csv("/content/time_series_l15years_rainfall.csv")
#ds =xr.open_mfdataset(['/content/drive/MyDrive/RF25_IMD0p252017.nc', '/content/drive/MyDrive/RF25_IMD0p252018.nc', '/content/drive/MyDrive/RF25_IMD0p252019.nc','/content/drive/MyDrive/RF25_IMD0p252020.nc','/content/RF25_IMD0p252021.nc'])
#ds = ds.sortby('TIME')
#for k in range (len(list1)):
#ds_latlon = ds.sel(LONGITUDE=longi, LATITUDE=lati)

#df = ds_latlon.to_dataframe()
lons=np.array(lons)
index = 100
list1 = np.delete(lons, index)
#print(arr)
#list1=lons.remove(77)
list1=list1.tolist()
#print(list1)
df=(df[df.LONGITUDE.isin(list1)==False])
lats=np.array(lats)
index = 75
list2 = np.delete(lats, index)
#print(arr)
#list1=lons.remove(77)
#print(list1)
list2=list2.tolist()
df=(df[df.LATITUDE.isin(list2)==False])
list= ["2020-02-29","2016-02-29","2012-02-29","2008-02-29","2004-02-29","2000-02-29","1996-02-29","1992-02-29"]
df=(df[df.TIME.isin(list)==False])

df=(df[df.TIME.isin(year_list1)==False])



df.drop(["LONGITUDE","LATITUDE"],axis=1,inplace=True)
df=df.rename(columns = {'RAINFALL' :'Grid_3'},inplace=False)
df.to_csv("Mawsynram_91.5826x25.2975l.csv")
# Out:
# [1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005
#  2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019
#  2020 2021]

# %%
df=pd.read_csv("Mawsynram_91.5826x25.2975l.csv")
df.head()
# Out:
#    Unnamed: 0        TIME  Grid_1
# 0     2653991  1992-06-01     0.0
# 1     2671406  1992-06-02     0.0
# 2     2688821  1992-06-03     0.0
# 3     2706236  1992-06-04     0.0
# 4     2723651  1992-06-05     0.0

# %%
lons=np.array(lons)
index = 42
list1 = np.delete(lons, index)
#print(arr)
#list1=lons.remove(77)
print(list1)
# Out:
# [ 66.5   66.75  67.    67.25  67.5   67.75  68.    68.25  68.5   68.75
#   69.    69.25  69.5   69.75  70.    70.25  70.5   70.75  71.    71.25
#   71.5   71.75  72.    72.25  72.5   72.75  73.    73.25  73.5   73.75
#   74.    74.25  74.5   74.75  75.    75.25  75.5   75.75  76.    76.25
#   76.5   76.75  77.25  77.5   77.75  78.    78.25  78.5   78.75  79.
#   79.25  79.5   79.75  80.    80.25  80.5   80.75  81.    81.25  81.5
#   81.75  82.    82.25  82.5   82.75  83.    83.25  83.5   83.75  84.
#   84.25  84.5   84.75  85.    85.25  85.5   85.75  86.    86.25  86.5
#   86.75  87.    87.25  87.5   87.75  88.    88.25  88.5   88.75  89.
#   89.25  89.5   89.75  90.    90.25  90.5   90.75  91.    91.25  91.5
#   91.75  92.    92.25  92.5   92.75  93.    93.25  93.5   93.75  94.
#   94.25  94.5   94.75  95.    95.25  95.5   95.75  96.    96.25  96.5
#   96.75  97.    97.25  97.5   97.75  98.    98.25  98.5   98.75  99.
#   99.25  99.5   99.75 100.  ]

# %%
print(122*5)
# Out:
# 610

# %%
year_list=[]
for i in range (30):
  a=1992+i
  #a="year"+str(a)
  year_list+=[a]
year_list=np.array(year_list)
#print(year_list)
list1=[]
month=[1,3,5]
for i in range (31):
  for j in month:
    for k in range (30):
      if i+1 <=9:
        a=str(year_list[k])+"-0"+str(j)+"-0"+str(i+1)
        list1 +=[a]
      else:
        a=str(year_list[k])+"-0"+str(j)+"-"+str(i+1)
        list1+=[a]
month=[4]
for i in range (30):
  for j in month:
    for k in range (30):
     if i+1 <=9:
        a=str(year_list[k])+"-0"+str(j)+"-0"+str(i+1)
        list1 +=[a]
     else:
        a=str(year_list[k])+"-0"+str(j)+"-"+str(i+1)
        list1+=[a]
month=[2]
for i in range (28):
  for j in month:
    for k in range (30):
     if i+1 <=9:
        a=str(year_list[k])+"-0"+str(j)+"-0"+str(i+1)
        list1 +=[a]
     else:
        a=str(year_list[k])+"-0"+str(j)+"-"+str(i+1)
        list1+=[a]
month=[10,12]
for i in range (31):
  for j in month:
    for k in range (30):
     if i+1 <=9:
        a=str(year_list[k])+"-"+str(j)+"-0"+str(i+1)
        list1 +=[a]
     else:
        a=str(year_list[k])+"-"+str(j)+"-"+str(i+1)
        list1+=[a]
month=[11]
for i in range (30):
  for j in month:
    for k in range (30):
     if i+1 <=9:
        a=str(year_list[k])+"-"+str(j)+"-0"+str(i+1)
        list1 +=[a]
     else:
        a=str(year_list[k])+"-"+str(j)+"-"+str(i+1)
        list1+=[a]
year_list1=np.array(list1)
year_list1=year_list1.tolist()
print(year_list1)
import xarray as xr
import pandas as pd
lon=[[44,67],[61,59],[29,48],[26,50]]
#latit=[22,23,24]
for i in range (4):
  #for j in range (len(latit)):
    df = pd.read_csv("/content/time_series_l15years_rainfall.csv")
#ds =xr.open_mfdataset(['/content/drive/MyDrive/RF25_IMD0p252017.nc', '/content/drive/MyDrive/RF25_IMD0p252018.nc', '/content/drive/MyDrive/RF25_IMD0p252019.nc','/content/drive/MyDrive/RF25_IMD0p252020.nc','/content/RF25_IMD0p252021.nc'])
#ds = ds.sortby('TIME')
#for k in range (len(list1)):
#ds_latlon = ds.sel(LONGITUDE=longi, LATITUDE=lati)

#df = ds_latlon.to_dataframe()
    lons=np.array(lons)
    index = lon[i][0]
    list1 = np.delete(lons, index)
#print(arr)
#list1=lons.remove(77)
    list1=list1.tolist()
    #print(list1)
    df=(df[df.LONGITUDE.isin(list1)==False])
    lats=np.array(lats)
    index = lon[i][1]
    list2 = np.delete(lats, index)
#print(arr)
#list1=lons.remove(77)
#print(list1)
    list2=list2.tolist()
    df=(df[df.LATITUDE.isin(list2)==False])
    list= ["2020-02-29","2016-02-29","2012-02-29","2008-02-29","2004-02-29","2000-02-29","1996-02-29","1992-02-29"]
    df=(df[df.TIME.isin(list)==False])

    df=(df[df.TIME.isin(year_list1)==False])



    #df=df.drop(["LONGITUDE","LATITUDE"],axis=1,inplace=True)
    #print=([lats][latit[j]])
    #df=df.rename(columns = {'RAINFALL' :'Grid_'+str(lats[int(latit[j])])+'x'+str(lons[int(longit[i])])},inplace=False)
    df.to_csv("rainfall"+str(lons[int(lon[i][0])])+'lx'+str(lats[int(lon[i][1])])+".csv")
# Out:
# ['1992-01-01', '1993-01-01', '1994-01-01', '1995-01-01', '1996-01-01', '1997-01-01', '1998-01-01', '1999-01-01', '2000-01-01', '2001-01-01', '2002-01-01', '2003-01-01', '2004-01-01', '2005-01-01', '2006-01-01', '2007-01-01', '2008-01-01', '2009-01-01', '2010-01-01', '2011-01-01', '2012-01-01', '2013-01-01', '2014-01-01', '2015-01-01', '2016-01-01', '2017-01-01', '2018-01-01', '2019-01-01', '2020-01-01', '2021-01-01', '1992-03-01', '1993-03-01', '1994-03-01', '1995-03-01', '1996-03-01', '1997-03-01', '1998-03-01', '1999-03-01', '2000-03-01', '2001-03-01', '2002-03-01', '2003-03-01', '2004-03-01', '2005-03-01', '2006-03-01', '2007-03-01', '2008-03-01', '2009-03-01', '2010-03-01', '2011-03-01', '2012-03-01', '2013-03-01', '2014-03-01', '2015-03-01', '2016-03-01', '2017-03-01', '2018-03-01', '2019-03-01', '2020-03-01', '2021-03-01', '1992-05-01', '1993-05-01', '1994-05-01', '1995-05-01', '1996-05-01', '1997-05-01', '1998-05-01', '1999-05-01', '2000-05-01', '2001-05-01', '2002-05-01', '20
# ...

# %%
from netCDF4 import Dataset
data= Dataset(r"/content/drive/MyDrive/RF25_IMD0p252017.nc")

print(data)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     history: FERRET V7.5 (optimized) 16-Mar-22
#     Conventions: CF-1.6
#     dimensions(sizes): LONGITUDE(135), LATITUDE(129), TIME(365)
#     variables(dimensions): float64 LONGITUDE(LONGITUDE), float64 LATITUDE(LATITUDE), float64 TIME(TIME), float64 RAINFALL(TIME, LATITUDE, LONGITUDE)
#     groups:

# %%
#import library
import pandas as pd

#add csv file to dataframe
df = pd.DataFrame({'Subject': ['English', 'Maths', 'Science'], 'Mean': [90, 87, 67]})

#create bar graph
bargraph = df.plot.bar(x = 'Subject', y = 'Mean', fontsize='9')

# %%
#import library
import pandas as pd

#add csv file to dataframe
df = pd.read_csv('/content/FINAL_30Years.csv')

#create bar graph
bargraph = df.plot.bar(x = 'TIME',y='Grid_1')

# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates
import numpy as np

plt.style.use('seaborn')
data = pd.read_csv("/content/FINAL_30Years.csv")
X=data[["TIME","Grid_1","Grid_2","Grid_4","Grid_5","Grid_6","Grid_7","Grid_8","Grid_9","Grid_10","Grid_11"]]
X['TIME'] = pd.to_datetime(X['TIME'])
X.sort_values('TIME', inplace=True)
#plt.plot(X["TIME"],X["Grid_3"],c="red")
#np.arange(3660)
#width=0.5
##ax.xaxis.set_major_locator(ticker.MultipleLocator(610))
#ax.xaxis.set_minor_locator(ticker.MultipleLocator(100))
#ax.yaxis.set_major_locator(ticker.MultipleLocator(100))
#ax.set_xticks(z)
#fig, ax = plt.subplots()
import matplotlib.pyplot as plt
ax=plt.axes()
x = np.arange(len(X["TIME"]))
w = 0.1
plt.bar(x-w, X["Grid_1"], color="red",label="Middle_India")
for i in range (4):
  plt.bar(x-(i+2)*w, X["Grid_"+str(i+8)], color="red")
'''plt.bar(x-2*w, X["Grid_8"], color="red")
plt.bar(x-3*w, X["Grid_9"], color="red")
plt.bar(X["TIME"], X["Grid_10"], color="red")
plt.bar(X["TIME"], X["Grid_11"], color="red")'''
#plt.xlabel("TIME")
#plt.ylabel("Grid_1)")
#plt.show()
plt.bar(x+w,X["Grid_2"],color="green",label='Rajasthan')
for i in range (4):
  plt.bar(x+(i+6)*w,X["Grid_"+str(i+4)],color="green")

'''plt.bar(X["TIME"],X["Grid_2"],color="green")
plt.bar(X["TIME"],X["Grid_5"],color="green")
plt.bar(X["TIME"],X["Grid_6"],color="green")
#plt.scatter(X["TIME"],X["Grid_7"],c="green")
#data.plot.bar(x = 'TIME',y='Grid_1')
plt.plot(X["TIME"],X["Grid_7"],c="green")'''
#plt.xticks(x, X["TIME"])
'''fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
ax.set_xticks([0,610,1220,1830])
ax.set_xticklabels(['zero','two','four','six'])'''
plt.ylim([0,400])

ax.set_xticks([0, 500, 1000, 1500, 2000, 2500, 3000, 3500])

# setting label for x tick
ax.set_xticklabels(['1992', '1996', '2000', '2004','2008','2012','2016','2020'])
plt.gcf().autofmt_xdate()
plt.xlabel("TIME")
plt.ylabel("Rainfall")
plt.tight_layout()
plt.title("Rajasthan_vs_Middle_India")
plt.legend( loc ="upper left")
plt.show()
# Out:
# <ipython-input-9-0ddb75665531>:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <ipython-input-9-0ddb75665531>:10: UserWarning: Parsing '13-06-1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   X['TIME'] = pd.to_datetime(X['TIME'])
# <ipython-input-9-0ddb75665531>:10: UserWarning: Parsing '14-06-1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   X['TIME'] = pd.to_datetime(X['TIME'])
# <ipython-input-9-0ddb75665531>:10: UserWarning: Parsing '15-06-1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   X['TIME'] = pd.to_datetime(X['TIME'])
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

X = np.linspace(-15, 15, 1024)
Y = np.sinc(X)

ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(16))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.5))

plt.plot(X, Y )
plt.plot(c = 'k')
plt.show()

# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

plt.style.use('seaborn')
import numpy as np

df = pd.read_csv("/content/FINAL_30Years.csv")
names = df['TIME'].values
x = np.arange(len(names))
w = 0.5
plt.bar(x-w, df['Grid_1'].values, width=w, label='Grid_1')
plt.bar(x, df['Grid_2'].values, width=w, label='Grid_2')
plt.bar(x+w, df['Grid_4'].values,width=w ,label='Grid_4')
#plt.plot(x, df['Target'].values, lw=2, label='Target')
#plt.xticks(x, names)
plt.ylim([0,300])
#plt.tight_layout()

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
df['TIME'] = pd.to_datetime(df['TIME'])
df.sort_values('TIME', inplace=True)
plt.gcf().autofmt_xdate()
plt.xlabel('X label')
plt.tight_layout()
#plt.savefig("CSVBarplots.png", bbox_inches="tight")
plt.show()
# Out:
# <ipython-input-16-84ff70d3a958>:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <ipython-input-16-84ff70d3a958>:22: UserWarning: Parsing '13-06-1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['TIME'] = pd.to_datetime(df['TIME'])
# <ipython-input-16-84ff70d3a958>:22: UserWarning: Parsing '14-06-1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['TIME'] = pd.to_datetime(df['TIME'])
# <ipython-input-16-84ff70d3a958>:22: UserWarning: Parsing '15-06-1992' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['TIME'] = pd.to_datetime(df['TIME'])
# ...

# %%
# Library Import(numpy and matplotlib)
import numpy as np
import matplotlib.pyplot as plot

# Make a data definition
a1 = [2.2, 2.7, 3.2, 3.7, 4.2, 4.7]
b1 = [2, 5, 8, 11, 14, 17]

a2 = [4, 10, 14, 20, 24, 32]
b2 = [2.3, 5.5, 11, 18, 8.9, 10.2]

r1 = np.arange(6)
width1 = 0.5

# Create the first subplot
plot.subplot(1, 2, 2)
plot.bar(r1, a1, width=width1)
plot.bar(r1 + width1, b1, width=width1)

# Create the second subplot
plot.subplot(1, 2, 1)
plot.bar(r1, a2, width=width1)
plot.bar(r1 + width1, b2, width=width1)

# Display the plot
plot.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Set the figure size
#plt.rcParams["figure.figsize"] = [7.00, 3.50]
#plt.rcParams["figure.autolayout"] = True

# Make a list of columns
columns = ["TIME" ,'Grid_1',"Grid_3"]

# Read a CSV file
df = pd.read_csv("/content/FINAL_30Years.csv", usecols=columns)

# Plot the lines
df.plot()

plt.show()

# %%
import pandas as pd
df = pd.read_csv('/content/FINAL_30Years.csv', delimiter=',')
list_of_rows = [list(columns) for columns in df.values]
print(list_of_rows)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-6fdb8525c078> in <module>
#       1 import pandas as pd
#       2 df = pd.read_csv('/content/FINAL_30Years.csv', delimiter=',')
# ----> 3 list_of_rows = [list(columns) for columns in df.values]
#       4 print(list_of_rows)
#
# <ipython-input-16-6fdb8525c078> in <listcomp>(.0)
#       1 import pandas as pd
#       2 df = pd.read_csv('/content/FINAL_30Years.csv', delimiter=',')
# ----> 3 list_of_rows = [list(columns) for columns in df.values]
#       4 print(list_of_rows)
#
# TypeError: 'list' object is not callable

# %%
import pandas as pd
df = pd.read_csv('/content/FINAL_30Years.csv', delimiter=',')
count=0
list1=[]
for colimns in df:
  count=count+1
  list1.append(columns["Grid_1"])
print(list1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-a1081ea7d540> in <module>
#       5 for colimns in df:
#       6   count=count+1
# ----> 7   list1.append(columns["Grid_1"])
#       8 print(list1)
#
# TypeError: list indices must be integers or slices, not str
